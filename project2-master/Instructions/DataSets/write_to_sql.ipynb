# %%
import psycopg2
import pandas as pd
import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt
import csv

# %%
from sqlalchemy import create_engine, inspect, func
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# %%
engine = create_engine('postgresql+psycopg2://koxrqvuuxugccs:6878ba0790ec132289e57f3ed6daa22ada7e6368bea3a7489f4c03cb2bfb9ff1@ec2-174-129-214-42.compute-1.amazonaws.com/d64jo158fls6ag')
connection = engine.connect()

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['metadata', 'prim_key', 'lines']

# %%
"""
DO NOT RUN

engine.execute('''create table lines (
	id INT,
	s0e0 INT,
	speaker VARCHAR(255),
	line_text INT,
	primary key(id)
    )''')
"""

# %%
"""
DO NOT RUN

engine.execute('''create table metadata(
	id INT,
	title VARCHAR (255),
	synoprsis VARCHAR(5000),
	imdb_rating DECIMAL,
	episode_no INT,
	primary key (episode_no)
)''')"""

# %%
"""
DO NOT RUN

engine.execute('''create table prim_key(
	s0e0 INT,
	ep_id INT,
	primary key (ep_id)
)''')"""

# %%
"""
DO NOT RUN

engine.execute("drop table prim_key")
"""

# %%
#lines_df = pd.read_csv("../../../DataSets/line_counts.csv")
#metadata_df_i = pd.read_csv("../../../DataSets/metadata.csv")
#prim_key_df = pd.read_csv("../../../DataSets/prim_key.csv")

# %%
"""
DO NOT RUN

metadata_df = metadata_df.drop(['Unnamed: 0'], axis=1)
"""

# %%
#DO NOT RUN lines_df.to_sql('lines', con=engine)

# %%
#DO NOT RUN metadata_df.to_sql('metadata', con=engine)

# %%
#DXO NOT RUN prim_key_df.to_sql('prim_key',con=engine)

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['lines', 'metadata', 'prim_key']

# %%
pd.read_sql('''
select * from lines
''', engine)
# Out:
#       index    id  s0e0                  speaker  line_text
# 0         0     0   101                   Angela          5
# 1         1     1   101  Documentary Crew Member          3
# 2         2     2   101                   Dwight         35
# 3         3     3   101                      Jan         12
# 4         4     4   101                      Jim         37
# 5         5     5   101                    Kevin          2
# 6         6     6   101                      Man          1
# 7         7     7   101                  Michael         97
# 8         8     8   101                   Michel          1
# 9         9     9   101                    Oscar          6
# 10       10    10   101                      Pam         46
# 11       11    11   101                  Phyllis          2
# 12       12    12   101                      Roy          5
# 13       13    13   101                     Ryan         10
# 14       14    14   101                  Stanley          5
# ...
